# %%
import ijson

file_path = "dblpv13_cleaned.json"
i = 0
objects = []
with open(file_path, "r") as file:
    parser = ijson.items(file, "item")

    for obj in parser:

        i += 1
        if i > 20:
            print(obj)
        if i > 25:
            break
# Out:
# {'_id': '53e99784b7602d9701f3f8c2', 'title': 'Foreword.', 'authors': [{'_id': '53f46210dabfaedf43634cba', 'name': 'El Mohajir, Mohammed', 'org': 'FSDM, USMBA, Fez, Morocco|c|', 'gid': '5b86c21ae1cd8e14a39e6b14', 'orgid': '5f71b2811c455f439fe3c5b7'}, {'name': 'Begdouri, Ahlame'}, {'_id': '560175f745cedb3395e5a536', 'name': 'El Mohajir, Badreddine'}, {'name': 'Zarghili, Arsalane', '_id': '560175f745cedb3395e5a539'}], 'venue': {'_id': '53a7314420f7420be8d31c79', 'raw': 'IEICE Transactions', 'raw_zh': None, 'publisher': None, 'type': 11}, 'year': 2012, 'keywords': ['Political Economy', 'Social Choice', 'Historical Perspective', 'Welfare Economic', '50th Anniversary'], 'n_citation': 6, 'page_start': '', 'page_end': '', 'lang': 'en', 'volume': '1', 'issue': 'Supplement 1', 'issn': '2212-3431', 'isbn': '978-1-4673-2724-4', 'doi': '10.1109/CIST.2012.6388046', 'pdf': None, 'url': ['http://dx.doi.org/10.1109/CIST.2012.6388046', 'http://ieeexplore.ieee.org/xpl/abstractAuthors.jsp?tp=&arnumber=6
# ...

# %%
print(i)
# Out:
# 5354309

# %%
import ijson

file_path = "dblpv13.json"
i = 0
objects = []
with open(file_path, "r") as file:
    for line in file:
        print(line)
        i = i + 1
        if i > 100:
            break
print(i)
# Out:
# [
#
# {
#
#     "_id" : "53e99784b7602d9701f3e3f5",
#
#     "title" : "3GIO.",
#
#     "venue" : {
#
#         "type" : NumberInt(0)
#
#     },
#
#     "year" : NumberInt(2011),
#
#     "keywords" : [
#
#
#
#     ],
#
#     "n_citation" : NumberInt(0),
#
#     "lang" : "en"
#
# },
#
# {
#
#     "_id" : "53e99784b7602d9701f3e133",
#
#     "title" : "The relationship between canopy parameters and spectrum of winter wheat under different irrigations in Hebei Province.",
#
#     "authors" : [
#
#         {
#
#             "_id" : "53f45728dabfaec09f209538",
#
#             "name" : "Peijuan Wang"
#
#         },
#
#         {
#
#             "_id" : "5601754345cedb3395e59457",
#
#             "name" : "Jiahua Zhang"
#
#         },
#
#         {
#
#             "_id" : "53f38438dabfae4b34a08928",
#
#             "name" : "Donghui Xie"
#
#         },
#
#         {
#
#             "_id" : "5601754345cedb3395e5945a",
#
#             "name" : "Yanyan Xu"
#
#         },
#
#         {
#
# ...
